# %% [markdown]
# The example of the APIChain was a start, but what if we want to add more apis to our llm calls.
# The holy grail of agents and tools. So instead of just using text, we can provide the llms with the tools we have and have it form a strategy on what tools to use. In this example we'll add the tool that allows for google searches in the mix.
#
#  This gives you a glimpse of where the industry is heading. We start coding the tools that code the tools and that English is the new programming language.

# %% [markdown]
# We begin the boilerplate setup

# %%
# %pip install -q langchain langchain-openai
# %pip install -q duckduckgo-search
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q python-dotenv
from dotenv import load_dotenv
load_dotenv()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# True

# %%
from langchain.tools import DuckDuckGoSearchRun
internet_searcher=DuckDuckGoSearchRun()
internet_searcher.invoke("who is patrick Debois?")
# Out:
# 'Patrick Debois is known as the godfather of DevOps. He is also the founder of the DevOpsDays volunteer-led event series which now has spread to more than 30 cities around the world, and the co-author of " The DevOps Handbook ." VDOMDHTMLtml> DOP 200: From Digital Twins to Management - A Conversation With Patrick Debois - YouTube #200: We\'ve reached episode 200!!! As we do with all our divide by 50 episodes, we... Patrick Debois led DevOpsDays from its inception in 2009 until 2014, and then Bridget Kromhout became the lead in 2015. She is also the co-host on the very popular podcast, Arrested DevOps. If you don\'t listen to it, you should. She stepped down in 2020 but stayed on the advisory board of DevOpsDays with Patrick. At DevOps days Austin 2022 I sat down with the godfather of DevOps, Patrick Debois to get his advice for those starting out in DevOps. Patrick talked about the importance of finding the next... Unsurprisingly, our distinguished speaker at the launch of Pulumi\'s in-person AI Talks, Patrick Debois, who coined the term "DevOps," has recently tuned into LLM and GenAI Ops using the Langchain framework.'

# %%
# Add search as a tool to the agent toolbox
from langchain.agents import Tool
tools = [
    Tool(
        name="Current Search",
        func=internet_searcher.run,
        description="useful for when you need to answer questions about current events or the current state of the world",
    ),
]

# Alternatively you can just add them as a tool
tools = [internet_searcher]

# %%
from _lessonshelper.pretty_print_callback_handler import PrettyPrintCallbackHandler
pretty_callback = PrettyPrintCallbackHandler()

# %% [markdown]
# Agents typically run multiple calls until they reach a goal. Therefore they have a memory.

# %%
# Give the agent memory
from langchain.memory import ConversationBufferMemory

memory = ConversationBufferMemory(memory_key="chat_history")

# Prepare the LLM for the agent to use
from langchain_openai import OpenAI
llm = OpenAI(temperature=0, callbacks=[pretty_callback])

# %% [markdown]
# To reach that goal , agents follow a strategy to get to that goal.
# And to act on it , they will have tools at their disposal.

# %%
# Now initialize the agent

from langchain import hub
from langchain.agents import AgentExecutor, create_react_agent

# Reason and act 
prompt = hub.pull("hwchase17/react")
model = llm

agent = create_react_agent(model, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools)
agent_executor.callbacks = [pretty_callback]

agent_executor.invoke({"input":"whats the current temperature in London?"})
# Out:
# [chain][start] - inputs {'input': 'whats the current temperature in London?'}
#
# =============
# [llm][start] - prompts: Answer the following questions as best you can. You have access to the following tools:
#
# duckduckgo_search: A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
#
# Use the following format:
#
# Question: the input question you must answer
# Thought: you should always think about what to do
# Action: the action to take, should be one of [duckduckgo_search]
# Action Input: the input to the action
# Observation: the result of the action
# ... (this Thought/Action/Action Input/Observation can repeat N times)
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
# Begin!
#
# Question: whats the current temperature in London?
# Thought:
# [llm][new_token]  I
# [llm][new_token]  should
# [llm][new_token]  use
# [llm][new_token]  a
# [llm][new_token]  search
# [llm][new_token]  engine
# [llm][new_token]  to
# [llm][new_token]  find
# [llm][new_token]  the
# [llm][new_token]  answer
# [llm][new_token]
# Action
# [llm][new_token] :
# [llm][new_token]  duck
# [llm][new_token] duck
# [llm][new_token] go
# [llm][new_token] _search
# [llm][new_token]
# Action
# [llm][new_token]  Input
# [llm][new_token] :
# [llm][new_token]  "
# [llm][new_token] current
# [llm][new_token]  temperature
# [llm][new_token]  in
# [llm][new_token]  London
# [llm][new_token] "
#
# =============
# [llm][end] - generation  I should use a search engine to find the answer
# Action: duckduckgo_search
# Action Input: "current temperature in London"
# [agent][action] - action: tool='duckduckgo_search' tool_input='current temperature in London' log=' I should use a search engine to find the answer\nAction: duckduckgo_search\nAction Input: "current temperature in London"'
#
# =============
# [llm][start] - prompts: Answer the following questions as best you can. You have access to the following tools:
#
# duckduckgo_search: A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
#
# Use the following format:
#
# Question: the input question you must answer
# Thought: you should always think about what to do
# Action: the action to take, should be one of [duckduckgo_search]
# Action Input: the input to the action
# Observation: the result of the action
# ... (this Thought/Action/Action Input/Observation can repeat N times)
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
# Begin!
#
# Question: whats the current temperature in London?
# Thought: I should use a search engine to find the answer
# Action: duckduckgo_search
# Action Input: "current temperature in London"
# Observation: The current temperature in London is 11 degrees Celsius, with a cloudy and sunny interval from late morning to late afternoon. The UV index is low, the pollution is low and the pollen data is unavailable. See the seven-day forecast for London with temperature, wind, visibility and more. The current temperature in London is 4 degrees Celsius, clear and sunny. The maximum daytime temperature is 6 degrees Celsius on Friday, and the minimum nighttime temperature is 0 degrees Celsius. The six-day forecast shows cloudy and rainy conditions from Saturday to Wednesday. View the weather with our interactive map Today Hourly 10-Day Calendar History Wundermap access_time 3:47 PM GMT on February 11, 2024 (GMT 0) | Updated 4 hours ago --° | 38° 51 °F like 51° Cloudy N 7 London Capital, Greater London, England (Great Britain), elevation 25 m Details Current conditions 9° Feels like 8° 0.4 mm 2 m/s Table Graph Night Morning Afternoon Evening Temperature high/low WindPrecip. Today 10 Feb. 9° / 7° 1.3 mm 2 m/s Open hourly forecast Sunday 11 Feb. 9° / 3° 0 mm 4 m/s Open hourly forecast Monday 12 Feb. 9° / 2° 0 mm 5 m/s
# Thought:
# [llm][new_token] I
# [llm][new_token]  should
# [llm][new_token]  check
# [llm][new_token]  the
# [llm][new_token]  source
# [llm][new_token]  of
# [llm][new_token]  this
# [llm][new_token]  information
# [llm][new_token]  to
# [llm][new_token]  make
# [llm][new_token]  sure
# [llm][new_token]  it
# [llm][new_token]  is
# [llm][new_token]  accurate
# [llm][new_token]
# Action
# [llm][new_token] :
# [llm][new_token]  duck
# [llm][new_token] duck
# [llm][new_token] go
# [llm][new_token] _search
# [llm][new_token]
# Action
# [llm][new_token]  Input
# [llm][new_token] :
# [llm][new_token]  "
# [llm][new_token] weather
# [llm][new_token]  in
# [llm][new_token]  London
# [llm][new_token] "
#
# =============
# [llm][end] - generation I should check the source of this information to make sure it is accurate
# Action: duckduckgo_search
# Action Input: "weather in London"
# [agent][action] - action: tool='duckduckgo_search' tool_input='weather in London' log='I should check the source of this information to make sure it is accurate\nAction: duckduckgo_search\nAction Input: "weather in London"'
#
# =============
# [llm][start] - prompts: Answer the following questions as best you can. You have access to the following tools:
#
# duckduckgo_search: A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
#
# Use the following format:
#
# Question: the input question you must answer
# Thought: you should always think about what to do
# Action: the action to take, should be one of [duckduckgo_search]
# Action Input: the input to the action
# Observation: the result of the action
# ... (this Thought/Action/Action Input/Observation can repeat N times)
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
# Begin!
#
# Question: whats the current temperature in London?
# Thought: I should use a search engine to find the answer
# Action: duckduckgo_search
# Action Input: "current temperature in London"
# Observation: The current temperature in London is 11 degrees Celsius, with a cloudy and sunny interval from late morning to late afternoon. The UV index is low, the pollution is low and the pollen data is unavailable. See the seven-day forecast for London with temperature, wind, visibility and more. The current temperature in London is 4 degrees Celsius, clear and sunny. The maximum daytime temperature is 6 degrees Celsius on Friday, and the minimum nighttime temperature is 0 degrees Celsius. The six-day forecast shows cloudy and rainy conditions from Saturday to Wednesday. View the weather with our interactive map Today Hourly 10-Day Calendar History Wundermap access_time 3:47 PM GMT on February 11, 2024 (GMT 0) | Updated 4 hours ago --° | 38° 51 °F like 51° Cloudy N 7 London Capital, Greater London, England (Great Britain), elevation 25 m Details Current conditions 9° Feels like 8° 0.4 mm 2 m/s Table Graph Night Morning Afternoon Evening Temperature high/low WindPrecip. Today 10 Feb. 9° / 7° 1.3 mm 2 m/s Open hourly forecast Sunday 11 Feb. 9° / 3° 0 mm 4 m/s Open hourly forecast Monday 12 Feb. 9° / 2° 0 mm 5 m/s
# Thought: I should check the source of this information to make sure it is accurate
# Action: duckduckgo_search
# Action Input: "weather in London"
# Observation: Find the current and forecast weather conditions for London (Greater London) from the Met Office. See the temperature, wind, visibility, humidity, UV index and pollution levels for today and the next seven days. Get the latest weather forecast for City of London (Greater London) from the Met Office. See the temperature, wind, visibility, humidity and UV index for today and the next six days. Check the weather symbols and chance of precipitation for each time period. 1 - 7 days 8 - 14 days Hourly Trending news Clouds map Weather Radar Satellites Models Today 7 Feb 90% 4.7 mm 10° / 2° 11 - 22 mph Tomorrow 8 Feb 90% 17 mm 12° / 2° 17 - 30 mph Friday 9 Feb 80% 3.1 mm 13° / 7° 21 - 38 mph Saturday 10 Feb 80% 3.2 mm 11° / 4° 6 - 12 mph Sunday 11 Feb 70% 1.1 mm 11° / 4° 11 - 21 mph Monday 12 Feb 9° / 3° 15 - 28 mph 11° 5° Heavy rain changing to partly cloudy by nighttime. Sunrise: 07:23 Sunset: 17:06 L UV L Pollution Mon 12 Feb 9° 6° Tue 13 Feb 10° 9° Wed 14 Feb 13° 11° Thu 15 Feb 14° 9° Fri 16 Feb 12° 8° Sat... 10-Day Calendar History Wundermap access_time 3:47 PM GMT on February 11, 2024 (GMT 0) | Updated 4 hours ago --° | 38° 51 °F like 51° Cloudy N 7
# Thought:
# [llm][new_token]  I
# [llm][new_token]  should
# [llm][new_token]  compare
# [llm][new_token]  this
# [llm][new_token]  information
# [llm][new_token]  with
# [llm][new_token]  other
# [llm][new_token]  sources
# [llm][new_token]  to
# [llm][new_token]  ensure
# [llm][new_token]  accuracy
# [llm][new_token]
# Action
# [llm][new_token] :
# [llm][new_token]  duck
# [llm][new_token] duck
# [llm][new_token] go
# [llm][new_token] _search
# [llm][new_token]
# Action
# [llm][new_token]  Input
# [llm][new_token] :
# [llm][new_token]  "
# [llm][new_token] weather
# [llm][new_token]  forecast
# [llm][new_token]  for
# [llm][new_token]  London
# [llm][new_token] "
#
# =============
# [llm][end] - generation  I should compare this information with other sources to ensure accuracy
# Action: duckduckgo_search
# Action Input: "weather forecast for London"
# [agent][action] - action: tool='duckduckgo_search' tool_input='weather forecast for London' log=' I should compare this information with other sources to ensure accuracy\nAction: duckduckgo_search\nAction Input: "weather forecast for London"'
#
# =============
# [llm][start] - prompts: Answer the following questions as best you can. You have access to the following tools:
#
# duckduckgo_search: A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
#
# Use the following format:
#
# Question: the input question you must answer
# Thought: you should always think about what to do
# Action: the action to take, should be one of [duckduckgo_search]
# Action Input: the input to the action
# Observation: the result of the action
# ... (this Thought/Action/Action Input/Observation can repeat N times)
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
# Begin!
#
# Question: whats the current temperature in London?
# Thought: I should use a search engine to find the answer
# Action: duckduckgo_search
# Action Input: "current temperature in London"
# Observation: The current temperature in London is 11 degrees Celsius, with a cloudy and sunny interval from late morning to late afternoon. The UV index is low, the pollution is low and the pollen data is unavailable. See the seven-day forecast for London with temperature, wind, visibility and more. The current temperature in London is 4 degrees Celsius, clear and sunny. The maximum daytime temperature is 6 degrees Celsius on Friday, and the minimum nighttime temperature is 0 degrees Celsius. The six-day forecast shows cloudy and rainy conditions from Saturday to Wednesday. View the weather with our interactive map Today Hourly 10-Day Calendar History Wundermap access_time 3:47 PM GMT on February 11, 2024 (GMT 0) | Updated 4 hours ago --° | 38° 51 °F like 51° Cloudy N 7 London Capital, Greater London, England (Great Britain), elevation 25 m Details Current conditions 9° Feels like 8° 0.4 mm 2 m/s Table Graph Night Morning Afternoon Evening Temperature high/low WindPrecip. Today 10 Feb. 9° / 7° 1.3 mm 2 m/s Open hourly forecast Sunday 11 Feb. 9° / 3° 0 mm 4 m/s Open hourly forecast Monday 12 Feb. 9° / 2° 0 mm 5 m/s
# Thought: I should check the source of this information to make sure it is accurate
# Action: duckduckgo_search
# Action Input: "weather in London"
# Observation: Find the current and forecast weather conditions for London (Greater London) from the Met Office. See the temperature, wind, visibility, humidity, UV index and pollution levels for today and the next seven days. Get the latest weather forecast for City of London (Greater London) from the Met Office. See the temperature, wind, visibility, humidity and UV index for today and the next six days. Check the weather symbols and chance of precipitation for each time period. 1 - 7 days 8 - 14 days Hourly Trending news Clouds map Weather Radar Satellites Models Today 7 Feb 90% 4.7 mm 10° / 2° 11 - 22 mph Tomorrow 8 Feb 90% 17 mm 12° / 2° 17 - 30 mph Friday 9 Feb 80% 3.1 mm 13° / 7° 21 - 38 mph Saturday 10 Feb 80% 3.2 mm 11° / 4° 6 - 12 mph Sunday 11 Feb 70% 1.1 mm 11° / 4° 11 - 21 mph Monday 12 Feb 9° / 3° 15 - 28 mph 11° 5° Heavy rain changing to partly cloudy by nighttime. Sunrise: 07:23 Sunset: 17:06 L UV L Pollution Mon 12 Feb 9° 6° Tue 13 Feb 10° 9° Wed 14 Feb 13° 11° Thu 15 Feb 14° 9° Fri 16 Feb 12° 8° Sat... 10-Day Calendar History Wundermap access_time 3:47 PM GMT on February 11, 2024 (GMT 0) | Updated 4 hours ago --° | 38° 51 °F like 51° Cloudy N 7
# Thought:  I should compare this information with other sources to ensure accuracy
# Action: duckduckgo_search
# Action Input: "weather forecast for London"
# Observation: 14° 9° Fri 16 Feb 12° 8° Sat 17 Feb 11° 7° Today Monday Tuesday Wednesday Thursday Friday Saturday Updated: 19:39 (UTC) on Sun 11 Feb 2024 Show full forecast Forecast table explained i Last 24... Get the latest weather forecast for London, including temperature, wind, visibility, UV and pollution. See the six-day forecast for today and the next week, with weather symbols and UV index. Today 11° 5° Heavy rain changing to partly cloudy by nighttime. Sunrise: 07:23 Sunset: 17:06 L UV L Pollution Mon 12 Feb 9° 6° Tue 13 Feb 10° 9° Wed 14 Feb 13° 11° Thu 15 Feb 14° 9° Fri 16 Feb 12°... 8 - 14 days Hourly Trending news Clouds map Weather Radar Satellites Models Today 7 Feb 90% 4.7 mm 10° / 2° 11 - 22 mph Tomorrow 8 Feb 90% 17 mm 12° / 2° 17 - 30 mph Friday 9 Feb 80% 3.1 mm 13° / 7° 21 - 38 mph Saturday 10 Feb 80% 3.2 mm 11° / 4° 6 - 12 mph Sunday 11 Feb 70% 1.1 mm 11° / 4° 11 - 21 mph Monday 12 Feb 9° / 3° 15 - 28 mph 10-Day Calendar History Wundermap access_time 3:47 PM GMT on February 11, 2024 (GMT 0) | Updated 4 hours ago --° | 38° 51 °F like 51° Cloudy N 7
# Thought:
# [llm][new_token]  I
# [llm][new_token]  now
# [llm][new_token]  know
# [llm][new_token]  the
# [llm][new_token]  final
# [llm][new_token]  answer
# [llm][new_token]
# Final Answer:
# [llm][new_token]  The current temperature in
# [llm][new_token]  London
# [llm][new_token]  is
# [llm][new_token]
# [llm][new_token] 11
# [llm][new_token]  degrees
# [llm][new_token]  Celsius
# [llm][new_token] ,
# [llm][new_token]  with
# [llm][new_token]  a
# [llm][new_token]  cloudy
# [llm][new_token]  and
# [llm][new_token]  sunny
# [llm][new_token]  interval
# [llm][new_token]  from
# [llm][new_token]  late
# [llm][new_token]  morning
# [llm][new_token]  to
# [llm][new_token]  late
# [llm][new_token]  afternoon
# [llm][new_token] .
# [llm][new_token]  The UV index
# [llm][new_token]  is
# [llm][new_token]  low
# [llm][new_token] ,
# [llm][new_token]  the
# [llm][new_token]  pollution
# [llm][new_token]  is
# [llm][new_token]  low
# [llm][new_token]  and
# [llm][new_token]  the
# [llm][new_token]  pollen
# [llm][new_token]  data
# [llm][new_token]  is
# [llm][new_token]  unavailable
# [llm][new_token] .
# [llm][new_token]  See
# [llm][new_token]  the
# [llm][new_token]  seven
# [llm][new_token] -day
# [llm][new_token]  forecast
# [llm][new_token]  for
# [llm][new_token]  London
# [llm][new_token]  with
# [llm][new_token]  temperature
# [llm][new_token] ,
# [llm][new_token]  wind
# [llm][new_token] ,
# [llm][new_token]  visibility
# [llm][new_token]  and
# [llm][new_token]  more
# [llm][new_token] .
# [llm][new_token]
#
# =============
# [llm][end] - generation  I now know the final answer
# Final Answer: The current temperature in London is 11 degrees Celsius, with a cloudy and sunny interval from late morning to late afternoon. The UV index is low, the pollution is low and the pollen data is unavailable. See the seven-day forecast for London with temperature, wind, visibility and more.
# [agent][finish] - finish: return_values={'output': 'The current temperature in London is 11 degrees Celsius, with a cloudy and sunny interval from late morning to late afternoon. The UV index is low, the pollution is low and the pollen data is unavailable. See the seven-day forecast for London with temperature, wind, visibility and more.'} log=' I now know the final answer\nFinal Answer: The current temperature in London is 11 degrees Celsius, with a cloudy and sunny interval from late morning to late afternoon. The UV index is low, the pollution is low and the pollen data is unavailable. See the seven-day forecast for London with temperature, wind, visibility and more.'
# [chain][end] - outputs: {'output': 'The current temperature in London is 11 degrees Celsius, with a cloudy and sunny interval from late morning to late afternoon. The UV index is low, the pollution is low and the pollen data is unavailable. See the seven-day forecast for London with temperature, wind, visibility and more.'}
# {'input': 'whats the current temperature in London?',
#  'output': 'The current temperature in London is 11 degrees Celsius, with a cloudy and sunny interval from late morning to late afternoon. The UV index is low, the pollution is low and the pollen data is unavailable. See the seven-day forecast for London with temperature, wind, visibility and more.'}
