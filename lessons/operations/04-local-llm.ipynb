# %%
# %pip install langchain ollama
# Out:
# Requirement already satisfied: langchain in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (0.0.279)
# Requirement already satisfied: ollama in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (0.0.9)
# Requirement already satisfied: PyYAML>=5.3 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (2.0.20)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (0.5.14)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (0.0.32)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (2.8.5)
# Requirement already satisfied: numpy<2,>=1 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (1.10.12)
# Requirement already satisfied: requests<3,>=2 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiohttp-cors<0.8.0,>=0.7.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ollama) (0.7.0)
# Requirement already satisfied: ctransformers<0.3.0,>=0.2.10 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ollama) (0.2.26)
# Requirement already satisfied: fuzzywuzzy[speedup]<0.19.0,>=0.18.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ollama) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ollama) (3.1.2)
# Requirement already satisfied: llama-cpp-python<0.2.0,>=0.1.67 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ollama) (0.1.83)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ollama) (4.66.1)
# Requirement already satisfied: validators<0.21.0,>=0.20.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ollama) (0.20.0)
# Requirement already satisfied: yaspin<3.0.0,>=2.3.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ollama) (2.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: huggingface-hub in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ctransformers<0.3.0,>=0.2.10->ollama) (0.16.4)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from ctransformers<0.3.0,>=0.2.10->ollama) (9.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: python-levenshtein>=0.12 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from fuzzywuzzy[speedup]<0.19.0,>=0.18.0->ollama) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.2->ollama) (2.1.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from llama-cpp-python<0.2.0,>=0.1.67->ollama) (4.7.1)
# Requirement already satisfied: diskcache>=5.6.1 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from llama-cpp-python<0.2.0,>=0.1.67->ollama) (5.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: decorator>=3.4.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from validators<0.21.0,>=0.20.0->ollama) (5.1.1)
# Requirement already satisfied: termcolor<3.0,>=2.3 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from yaspin<3.0.0,>=2.3.0->ollama) (2.3.0)
# Requirement already satisfied: packaging>=17.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: Levenshtein==0.21.1 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]<0.19.0,>=0.18.0->ollama) (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from Levenshtein==0.21.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]<0.19.0,>=0.18.0->ollama) (3.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: filelock in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from huggingface-hub->ctransformers<0.3.0,>=0.2.10->ollama) (3.12.3)
# Requirement already satisfied: fsspec in /Users/patrick.debois/Library/Caches/pypoetry/virtualenvs/london-devops-VW7lFx7f-py3.11/lib/python3.11/site-packages (from huggingface-hub->ctransformers<0.3.0,>=0.2.10->ollama) (2023.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.llms import Ollama

prompt = "What is DevOps ? Please be verbose and detailed in your answer."
llm = Ollama(model="llama2-uncensored")

import sys
sys.path.append('../developer')

from _lessonshelper.pretty_print_callback_handler import PrettyPrintCallbackHandler
pretty_callback = PrettyPrintCallbackHandler()
llm.callbacks = [pretty_callback]
result = llm(prompt,  streaming=True)
# Out:
# =============
# [llm][start] - prompts: What is DevOps ? Please be verbose and detailed in your answer.
# [llm][new_token] Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  stands
# [llm][new_token]  for
# [llm][new_token]  Development
# [llm][new_token]  Oper
# [llm][new_token] ations
# [llm][new_token] ,
# [llm][new_token]  which
# [llm][new_token]  refers
# [llm][new_token]  to
# [llm][new_token]  a
# [llm][new_token]  software
# [llm][new_token]  development
# [llm][new_token]  method
# [llm][new_token] ology
# [llm][new_token]  that
# [llm][new_token]  comb
# [llm][new_token] ines
# [llm][new_token]  software
# [llm][new_token]  development
# [llm][new_token]  (
# [llm][new_token] Dev
# [llm][new_token] )
# [llm][new_token]  with
# [llm][new_token]  IT
# [llm][new_token]  operations
# [llm][new_token]  (
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token] ).
# [llm][new_token]  The
# [llm][new_token]  goal
# [llm][new_token]  of
# [llm][new_token]  this
# [llm][new_token]  approach
# [llm][new_token]  is
# [llm][new_token]  to
# [llm][new_token]  improve
# [llm][new_token]  the
# [llm][new_token]  collaboration
# [llm][new_token]  between
# [llm][new_token]  developers
# [llm][new_token]  and
# [llm][new_token]  operators
# [llm][new_token] ,
# [llm][new_token]  en
# [llm][new_token] abling
# [llm][new_token]  faster
# [llm][new_token]  delivery
# [llm][new_token]  of
# [llm][new_token]  software
# [llm][new_token]  while
# [llm][new_token]  ens
# [llm][new_token] uring
# [llm][new_token]  quality
# [llm][new_token]  and
# [llm][new_token]  reli
# [llm][new_token] ability
# [llm][new_token] .
# [llm][new_token]
# [llm][new_token]
#
# [llm][new_token] Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  typically
# [llm][new_token]  involves
# [llm][new_token]  autom
# [llm][new_token] ating
# [llm][new_token]  processes
# [llm][new_token]  such
# [llm][new_token]  as
# [llm][new_token]  testing
# [llm][new_token] ,
# [llm][new_token]  deployment
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  monitoring
# [llm][new_token] ,
# [llm][new_token]  which
# [llm][new_token]  can
# [llm][new_token]  help
# [llm][new_token]  teams
# [llm][new_token]  work
# [llm][new_token]  more
# [llm][new_token]  efficiently
# [llm][new_token]  and
# [llm][new_token]  reduce
# [llm][new_token]  the
# [llm][new_token]  risk
# [llm][new_token]  of
# [llm][new_token]  errors
# [llm][new_token] .
# [llm][new_token]  It
# [llm][new_token]  also
# [llm][new_token]  emphas
# [llm][new_token] izes
# [llm][new_token]  communication
# [llm][new_token] ,
# [llm][new_token]  collaboration
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  trans
# [llm][new_token] par
# [llm][new_token] ency
# [llm][new_token]  among
# [llm][new_token]  team
# [llm][new_token]  members
# [llm][new_token] ,
# [llm][new_token]  with
# [llm][new_token]  the
# [llm][new_token]  aim
# [llm][new_token]  of
# [llm][new_token]  creating
# [llm][new_token]  a
# [llm][new_token]  culture
# [llm][new_token]  that
# [llm][new_token]  values
# [llm][new_token]  continuous
# [llm][new_token]  improvement
# [llm][new_token]  and
# [llm][new_token]  innov
# [llm][new_token] ation
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] In
# [llm][new_token]  terms
# [llm][new_token]  of
# [llm][new_token]  implementation
# [llm][new_token] ,
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  typically
# [llm][new_token]  involves
# [llm][new_token]  adopt
# [llm][new_token] ing
# [llm][new_token]  new
# [llm][new_token]  tools
# [llm][new_token]  and
# [llm][new_token]  techn
# [llm][new_token] ologies
# [llm][new_token]  that
# [llm][new_token]  facil
# [llm][new_token] itate
# [llm][new_token]  autom
# [llm][new_token] ated
# [llm][new_token]  testing
# [llm][new_token] ,
# [llm][new_token]  deployment
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  monitoring
# [llm][new_token] .
# [llm][new_token]  Additionally
# [llm][new_token] ,
# [llm][new_token]  teams
# [llm][new_token]  may
# [llm][new_token]  implement
# [llm][new_token]  Ag
# [llm][new_token] ile
# [llm][new_token]  or
# [llm][new_token]  Le
# [llm][new_token] an
# [llm][new_token]  method
# [llm][new_token] ologies
# [llm][new_token]  to
# [llm][new_token]  ensure
# [llm][new_token]  continuous
# [llm][new_token]  feedback
# [llm][new_token]  and
# [llm][new_token]  iter
# [llm][new_token] ative
# [llm][new_token]  improvement
# [llm][new_token]  throughout
# [llm][new_token]  the
# [llm][new_token]  development
# [llm][new_token]  process
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] Over
# [llm][new_token] all
# [llm][new_token] ,
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  is
# [llm][new_token]  a
# [llm][new_token]  highly
# [llm][new_token]  effective
# [llm][new_token]  approach
# [llm][new_token]  to
# [llm][new_token]  software
# [llm][new_token]  development
# [llm][new_token]  that
# [llm][new_token]  can
# [llm][new_token]  help
# [llm][new_token]  organizations
# [llm][new_token]  deliver
# [llm][new_token]  high
# [llm][new_token] -
# [llm][new_token] quality
# [llm][new_token]  products
# [llm][new_token]  faster
# [llm][new_token]  while
# [llm][new_token]  impro
# [llm][new_token] ving
# [llm][new_token]  efficiency
# [llm][new_token]  and
# [llm][new_token]  reducing
# [llm][new_token]  ris
# [llm][new_token] ks
# [llm][new_token] .
# [llm][new_token]
#
# =============
# [llm][end] - generation DevOps stands for Development Operations, which refers to a software development methodology that combines software development (Dev) with IT operations (Ops). The goal of this approach is to improve the collaboration between developers and operators, enabling faster delivery of software while ensuring quality and reliability.
# DevOps typically involves automating processes such as testing, deployment, and monitoring, which can help teams work more efficiently and reduce the risk of errors. It also emphasizes communication, collaboration, and transparency among team members, with the aim of creating a culture that values continuous improvement and innovation.
# In terms of implementation, DevOps typically involves adopting new tools and technologies that facilitate automated testing, deployment, and monitoring. Additionally, teams may implement Agile or Lean methodologies to ensure continuous feedback and iterative improvement throughout the development process.
# Overall, DevOps is a highly effective approach to software development that can help organizations deliver high-quality products faster while improving efficiency and reducing risks.
