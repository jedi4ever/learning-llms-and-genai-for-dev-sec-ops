# %% [markdown]
# As a developer you might want to run your own llm locally.
# There are multiple providers for this.
# In this example we'll use Ollama <https://ollama.ai/>
#
# What is interesting about that is that they have an interface similar to Dockerfiles but with a Modelfile.

# %% [markdown]
# ```
# Usage:
#   ollama [command]
#
# Available Commands:
#   serve       Start ollama
#   create      Create a model from a Modelfile
#   run         Run a model
#   pull        Pull a model from a registry
#   push        Push a model to a registry
#   list        List models
#   cp          Copy a model
#   rm          Remove a model
#   help        Help about any command
# ```

# %% [markdown]
# From https://github.com/jmorganca/ollama/blob/main/examples/devops-engineer/Modelfile
# ```
# Modelfile for creating a devops engineer assistant
# # Run `ollama create devops-engineer -f ./Modelfile` and then `ollama run devops-engineer` and enter a topic
#
# FROM llama2:13b
# PARAMETER temperature 1
# SYSTEM """
# You are a senior devops engineer, acting as an assistant. You offer help with cloud technologies like: Terraform, AWS, kubernetes, python. You answer with code examples when possible
# """
# ```

# %% [markdown]
# ```
# % ./ollama  list
# NAME                    	SIZE  	MODIFIED
# llama2:13b              	7.3 GB	3 weeks ago
# llama2:latest           	3.8 GB	3 weeks ago
# llama2-uncensored:latest	3.8 GB	3 weeks ago
# ```

# %%
# %pip install langchain==0.0.281 ollama
# Out:
# Requirement already satisfied: langchain==0.0.281 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (0.0.281)
# Requirement already satisfied: ollama in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (0.0.9)
# Requirement already satisfied: PyYAML>=5.3 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (2.0.20)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (0.5.14)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (0.0.33)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (2.8.5)
# Requirement already satisfied: numpy<2,>=1 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (1.10.12)
# Requirement already satisfied: requests<3,>=2 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from langchain==0.0.281) (8.2.3)
# Requirement already satisfied: aiohttp-cors<0.8.0,>=0.7.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ollama) (0.7.0)
# Requirement already satisfied: ctransformers<0.3.0,>=0.2.10 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ollama) (0.2.26)
# Requirement already satisfied: fuzzywuzzy[speedup]<0.19.0,>=0.18.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ollama) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ollama) (3.1.2)
# Requirement already satisfied: llama-cpp-python<0.2.0,>=0.1.67 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ollama) (0.1.83)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ollama) (4.66.1)
# Requirement already satisfied: validators<0.21.0,>=0.20.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ollama) (0.20.0)
# Requirement already satisfied: yaspin<3.0.0,>=2.3.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ollama) (2.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.281) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.281) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.281) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.281) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.281) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.281) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.281) (1.3.1)
# Requirement already satisfied: huggingface-hub in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ctransformers<0.3.0,>=0.2.10->ollama) (0.16.4)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from ctransformers<0.3.0,>=0.2.10->ollama) (9.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.281) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.281) (0.9.0)
# Requirement already satisfied: python-levenshtein>=0.12 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from fuzzywuzzy[speedup]<0.19.0,>=0.18.0->ollama) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.2->ollama) (2.1.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from llama-cpp-python<0.2.0,>=0.1.67->ollama) (4.7.1)
# Requirement already satisfied: diskcache>=5.6.1 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from llama-cpp-python<0.2.0,>=0.1.67->ollama) (5.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.0.281) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.0.281) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.0.281) (2023.7.22)
# Requirement already satisfied: decorator>=3.4.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from validators<0.21.0,>=0.20.0->ollama) (5.1.1)
# Requirement already satisfied: termcolor<3.0,>=2.3 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from yaspin<3.0.0,>=2.3.0->ollama) (2.3.0)
# Requirement already satisfied: packaging>=17.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.281) (23.1)
# Requirement already satisfied: Levenshtein==0.21.1 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]<0.19.0,>=0.18.0->ollama) (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from Levenshtein==0.21.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]<0.19.0,>=0.18.0->ollama) (3.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.281) (1.0.0)
# Requirement already satisfied: filelock in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from huggingface-hub->ctransformers<0.3.0,>=0.2.10->ollama) (3.12.3)
# Requirement already satisfied: fsspec in /Volumes/home-ssd/patrick/Library/Caches/pypoetry/virtualenvs/london-devops-2Fa23Xyl-py3.11/lib/python3.11/site-packages (from huggingface-hub->ctransformers<0.3.0,>=0.2.10->ollama) (2023.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We set up the usual boilerplate

# %%
# A bit of trickery to load the handler from a top directory
import sys
sys.path.append('../developer')
from _lessonshelper.pretty_print_callback_handler import PrettyPrintCallbackHandler
pretty_callback = PrettyPrintCallbackHandler()

# %% [markdown]
# To make a call similar to OpenAI we just instantiate from Ollama

# %%
#from langchain.llms import OpenAI
from langchain.llms import Ollama

# for comparison
# llm = OpenAI()
llm = Ollama(model="llama2-uncensored")

llm.callbacks = [pretty_callback]

prompt = "What is DevOps ? Please be verbose and detailed in your answer."
result = llm(prompt,  streaming=True)
# Out:
# =============
# [llm][start] - prompts: What is DevOps ? Please be verbose and detailed in your answer.
# [llm][new_token] Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  is
# [llm][new_token]  a
# [llm][new_token]  software
# [llm][new_token]  development
# [llm][new_token]  method
# [llm][new_token] ology
# [llm][new_token]  that
# [llm][new_token]  emphas
# [llm][new_token] izes
# [llm][new_token]  collaboration
# [llm][new_token]  between
# [llm][new_token]  developers
# [llm][new_token] ,
# [llm][new_token]  system
# [llm][new_token]  operators
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  other
# [llm][new_token]  IT
# [llm][new_token]  profession
# [llm][new_token] als
# [llm][new_token]  to
# [llm][new_token]  ensure
# [llm][new_token]  faster
# [llm][new_token]  delivery
# [llm][new_token]  of
# [llm][new_token]  high
# [llm][new_token] -
# [llm][new_token] quality
# [llm][new_token]  software
# [llm][new_token]  products
# [llm][new_token] .
# [llm][new_token]  It
# [llm][new_token]  a
# [llm][new_token] ims
# [llm][new_token]  to
# [llm][new_token]  bridge
# [llm][new_token]  the
# [llm][new_token]  gap
# [llm][new_token]  between
# [llm][new_token]  Development
# [llm][new_token]  (
# [llm][new_token] Dev
# [llm][new_token] )
# [llm][new_token]  and
# [llm][new_token]  Oper
# [llm][new_token] ations
# [llm][new_token]  (
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token] ),
# [llm][new_token]  by
# [llm][new_token]  bringing
# [llm][new_token]  together
# [llm][new_token]  multiple
# [llm][new_token]  teams
# [llm][new_token]  responsible
# [llm][new_token]  for
# [llm][new_token]  various
# [llm][new_token]  aspects
# [llm][new_token]  of
# [llm][new_token]  application
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  deployment
# [llm][new_token] .
# [llm][new_token]  The
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  approach
# [llm][new_token]  is
# [llm][new_token]  based
# [llm][new_token]  on
# [llm][new_token]  continuous
# [llm][new_token]  integration
# [llm][new_token]  and
# [llm][new_token]  continuous
# [llm][new_token]  delivery
# [llm][new_token]  principles
# [llm][new_token] ,
# [llm][new_token]  which
# [llm][new_token]  involve
# [llm][new_token]  autom
# [llm][new_token] ating
# [llm][new_token]  all
# [llm][new_token]  stages
# [llm][new_token]  of
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  testing
# [llm][new_token]  to
# [llm][new_token]  minim
# [llm][new_token] ize
# [llm][new_token]  errors
# [llm][new_token]  and
# [llm][new_token]  improve
# [llm][new_token]  efficiency
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] In
# [llm][new_token]  addition
# [llm][new_token]  to
# [llm][new_token]  the
# [llm][new_token]  collaboration
# [llm][new_token]  between
# [llm][new_token]  different
# [llm][new_token]  teams
# [llm][new_token] ,
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  also
# [llm][new_token]  involves
# [llm][new_token]  the
# [llm][new_token]  use
# [llm][new_token]  of
# [llm][new_token]  modern
# [llm][new_token]  tools
# [llm][new_token]  and
# [llm][new_token]  techniques
# [llm][new_token]  such
# [llm][new_token]  as
# [llm][new_token]  container
# [llm][new_token] ization
# [llm][new_token] ,
# [llm][new_token]  infrastr
# [llm][new_token] ucture
# [llm][new_token]  as
# [llm][new_token]  code
# [llm][new_token]  (
# [llm][new_token] I
# [llm][new_token] a
# [llm][new_token] C
# [llm][new_token] ),
# [llm][new_token]  and
# [llm][new_token]  configuration
# [llm][new_token]  management
# [llm][new_token]  (
# [llm][new_token] CM
# [llm][new_token] ).
# [llm][new_token]  These
# [llm][new_token]  tools
# [llm][new_token]  enable
# [llm][new_token]  developers
# [llm][new_token]  to
# [llm][new_token]  build
# [llm][new_token]  and
# [llm][new_token]  deploy
# [llm][new_token]  applications
# [llm][new_token]  faster
# [llm][new_token] ,
# [llm][new_token]  while
# [llm][new_token]  reducing
# [llm][new_token]  manual
# [llm][new_token]  inter
# [llm][new_token] vention
# [llm][new_token]  and
# [llm][new_token]  human
# [llm][new_token]  error
# [llm][new_token] .
# [llm][new_token]  This
# [llm][new_token]  results
# [llm][new_token]  in
# [llm][new_token]  a
# [llm][new_token]  more
# [llm][new_token]  efficient
# [llm][new_token]  software
# [llm][new_token]  development
# [llm][new_token]  process
# [llm][new_token] ,
# [llm][new_token]  where
# [llm][new_token]  feedback
# [llm][new_token]  loops
# [llm][new_token]  are
# [llm][new_token]  shorter
# [llm][new_token]  and
# [llm][new_token]  mistakes
# [llm][new_token]  are
# [llm][new_token]  minim
# [llm][new_token] ized
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] The
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  approach
# [llm][new_token]  is
# [llm][new_token]  based
# [llm][new_token]  on
# [llm][new_token]  several
# [llm][new_token]  key
# [llm][new_token]  principles
# [llm][new_token] ,
# [llm][new_token]  including
# [llm][new_token]  autom
# [llm][new_token] ation
# [llm][new_token] ,
# [llm][new_token]  collaboration
# [llm][new_token] ,
# [llm][new_token]  monitoring
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  communication
# [llm][new_token] .
# [llm][new_token]  Autom
# [llm][new_token] ating
# [llm][new_token]  repet
# [llm][new_token] itive
# [llm][new_token]  tasks
# [llm][new_token]  and
# [llm][new_token]  processes
# [llm][new_token]  helps
# [llm][new_token]  reduce
# [llm][new_token]  errors
# [llm][new_token]  and
# [llm][new_token]  increases
# [llm][new_token]  efficiency
# [llm][new_token] ,
# [llm][new_token]  while
# [llm][new_token]  encourag
# [llm][new_token] ing
# [llm][new_token]  collaboration
# [llm][new_token]  between
# [llm][new_token]  developers
# [llm][new_token]  and
# [llm][new_token]  operators
# [llm][new_token]  enables
# [llm][new_token]  the
# [llm][new_token]  sharing
# [llm][new_token]  of
# [llm][new_token]  knowledge
# [llm][new_token]  and
# [llm][new_token]  expert
# [llm][new_token] ise
# [llm][new_token] .
# [llm][new_token]  Mon
# [llm][new_token] itor
# [llm][new_token] ing
# [llm][new_token]  tools
# [llm][new_token]  help
# [llm][new_token]  identify
# [llm][new_token]  issues
# [llm][new_token]  as
# [llm][new_token]  they
# [llm][new_token]  occur
# [llm][new_token] ,
# [llm][new_token]  allowing
# [llm][new_token]  teams
# [llm][new_token]  to
# [llm][new_token]  quickly
# [llm][new_token]  address
# [llm][new_token]  any
# [llm][new_token]  problems
# [llm][new_token]  that
# [llm][new_token]  arise
# [llm][new_token] .
# [llm][new_token]  Finally
# [llm][new_token] ,
# [llm][new_token]  effective
# [llm][new_token]  communication
# [llm][new_token]  between
# [llm][new_token]  different
# [llm][new_token]  teams
# [llm][new_token]  is
# [llm][new_token]  essential
# [llm][new_token]  for
# [llm][new_token]  successful
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  practices
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] Over
# [llm][new_token] all
# [llm][new_token] ,
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  is
# [llm][new_token]  a
# [llm][new_token]  highly
# [llm][new_token]  effective
# [llm][new_token]  approach
# [llm][new_token]  to
# [llm][new_token]  software
# [llm][new_token]  development
# [llm][new_token] ,
# [llm][new_token]  en
# [llm][new_token] abling
# [llm][new_token]  organizations
# [llm][new_token]  to
# [llm][new_token]  deliver
# [llm][new_token]  high
# [llm][new_token] -
# [llm][new_token] quality
# [llm][new_token]  products
# [llm][new_token]  faster
# [llm][new_token]  and
# [llm][new_token]  more
# [llm][new_token]  efficiently
# [llm][new_token]  than
# [llm][new_token]  ever
# [llm][new_token]  before
# [llm][new_token] .
# [llm][new_token]  By
# [llm][new_token]  lever
# [llm][new_token] aging
# [llm][new_token]  modern
# [llm][new_token]  tools
# [llm][new_token]  and
# [llm][new_token]  techniques
# [llm][new_token] ,
# [llm][new_token]  teams
# [llm][new_token]  can
# [llm][new_token]  work
# [llm][new_token]  together
# [llm][new_token]  se
# [llm][new_token] am
# [llm][new_token] lessly
# [llm][new_token]  to
# [llm][new_token]  create
# [llm][new_token]  and
# [llm][new_token]  deploy
# [llm][new_token]  applications
# [llm][new_token]  that
# [llm][new_token]  meet
# [llm][new_token]  the
# [llm][new_token]  needs
# [llm][new_token]  of
# [llm][new_token]  their
# [llm][new_token]  customers
# [llm][new_token]  and
# [llm][new_token]  st
# [llm][new_token] ake
# [llm][new_token] hold
# [llm][new_token] ers
# [llm][new_token] .
# [llm][new_token]
#
# =============
# [llm][end] - generation DevOps is a software development methodology that emphasizes collaboration between developers, system operators, and other IT professionals to ensure faster delivery of high-quality software products. It aims to bridge the gap between Development (Dev) and Operations (Ops), by bringing together multiple teams responsible for various aspects of application development and deployment. The DevOps approach is based on continuous integration and continuous delivery principles, which involve automating all stages of development and testing to minimize errors and improve efficiency.
# In addition to the collaboration between different teams, DevOps also involves the use of modern tools and techniques such as containerization, infrastructure as code (IaC), and configuration management (CM). These tools enable developers to build and deploy applications faster, while reducing manual intervention and human error. This results in a more efficient software development process, where feedback loops are shorter and mistakes are minimized.
# The DevOps approach is based on several key principles, including automation, collaboration, monitoring, and communication. Automating repetitive tasks and processes helps reduce errors and increases efficiency, while encouraging collaboration between developers and operators enables the sharing of knowledge and expertise. Monitoring tools help identify issues as they occur, allowing teams to quickly address any problems that arise. Finally, effective communication between different teams is essential for successful DevOps practices.
# Overall, DevOps is a highly effective approach to software development, enabling organizations to deliver high-quality products faster and more efficiently than ever before. By leveraging modern tools and techniques, teams can work together seamlessly to create and deploy applications that meet the needs of their customers and stakeholders.
