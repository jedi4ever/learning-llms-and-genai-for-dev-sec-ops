# %% [markdown]
# As a developer you might want to run your own llm locally.
# There are multiple providers for this.
# In this example we'll use Ollama <https://ollama.ai/>
#
# What is interesting about that is that they have an interface similar to Dockerfiles but with a Modelfile.

# %% [markdown]
# ```
# Usage:
#   ollama [command]
#
# Available Commands:
#   serve       Start ollama
#   create      Create a model from a Modelfile
#   run         Run a model
#   pull        Pull a model from a registry
#   push        Push a model to a registry
#   list        List models
#   cp          Copy a model
#   rm          Remove a model
#   help        Help about any command
# ```

# %% [markdown]
# From https://github.com/jmorganca/ollama/blob/main/examples/devops-engineer/Modelfile
# ```
# Modelfile for creating a devops engineer assistant
# # Run `ollama create devops-engineer -f ./Modelfile` and then `ollama run devops-engineer` and enter a topic
#
# FROM llama2:13b
# PARAMETER temperature 1
# SYSTEM """
# You are a senior devops engineer, acting as an assistant. You offer help with cloud technologies like: Terraform, AWS, kubernetes, python. You answer with code examples when possible
# """
# ```

# %% [markdown]
# ```
# % ./ollama  list
# NAME                    	SIZE  	MODIFIED
# llama2:13b              	7.3 GB	3 weeks ago
# llama2:latest           	3.8 GB	3 weeks ago
# llama2-uncensored:latest	3.8 GB	3 weeks ago
# ```

# %%
# %pip install -q langchain langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We set up the usual boilerplate

# %%
# A bit of trickery to load the handler from a top directory
import sys
sys.path.append('../developer')
from _lessonshelper.pretty_print_callback_handler import PrettyPrintCallbackHandler
pretty_callback = PrettyPrintCallbackHandler()

# %% [markdown]
# To make a call similar to OpenAI we just instantiate from Ollama

# %%
#from langchain.llms import OpenAI
from langchain_community.chat_models import ChatOllama

# for comparison
# llm = OpenAI()
llm = ChatOllama(model="llama2:7b-chat", temperature=0, callbacks=[pretty_callback])

llm.callbacks = [pretty_callback]

prompt = "What is DevOps ? Please be verbose and detailed in your answer."
result = llm.invoke(prompt)
# Out:
# [chat_model][start] - prompts : What is DevOps ? Please be verbose and detailed in your answer.
# [llm][new_token]
#
# [llm][new_token] Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  is
# [llm][new_token]  a
# [llm][new_token]  set
# [llm][new_token]  of
# [llm][new_token]  practices
# [llm][new_token]  that
# [llm][new_token]  comb
# [llm][new_token] ines
# [llm][new_token]  software
# [llm][new_token]  development
# [llm][new_token]  (
# [llm][new_token] Dev
# [llm][new_token] )
# [llm][new_token]  and
# [llm][new_token]  information
# [llm][new_token]  technology
# [llm][new_token]  operations
# [llm][new_token]  (
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token] )
# [llm][new_token]  to
# [llm][new_token]  enh
# [llm][new_token] ance
# [llm][new_token]  collaboration
# [llm][new_token] ,
# [llm][new_token]  communication
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  autom
# [llm][new_token] ation
# [llm][new_token]  between
# [llm][new_token]  these
# [llm][new_token]  two
# [llm][new_token]  groups
# [llm][new_token] .
# [llm][new_token]  The
# [llm][new_token]  primary
# [llm][new_token]  goal
# [llm][new_token]  of
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  is
# [llm][new_token]  to
# [llm][new_token]  break
# [llm][new_token]  down
# [llm][new_token]  the
# [llm][new_token]  sil
# [llm][new_token] os
# [llm][new_token]  between
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  operations
# [llm][new_token]  teams
# [llm][new_token]  and
# [llm][new_token]  create
# [llm][new_token]  a
# [llm][new_token]  more
# [llm][new_token]  stream
# [llm][new_token] lined
# [llm][new_token]  and
# [llm][new_token]  efficient
# [llm][new_token]  approach
# [llm][new_token]  to
# [llm][new_token]  software
# [llm][new_token]  delivery
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token]
#
# [llm][new_token] At
# [llm][new_token]  its
# [llm][new_token]  core
# [llm][new_token] ,
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  is
# [llm][new_token]  about
# [llm][new_token]  creating
# [llm][new_token]  a
# [llm][new_token]  culture
# [llm][new_token]  of
# [llm][new_token]  collaboration
# [llm][new_token]  and
# [llm][new_token]  trust
# [llm][new_token]  between
# [llm][new_token]  developers
# [llm][new_token]  and
# [llm][new_token]  operators
# [llm][new_token] .
# [llm][new_token]  It
# [llm][new_token]  involves
# [llm][new_token]  tre
# [llm][new_token] ating
# [llm][new_token]  the
# [llm][new_token]  entire
# [llm][new_token]  software
# [llm][new_token]  delivery
# [llm][new_token]  process
# [llm][new_token]  as
# [llm][new_token]  a
# [llm][new_token]  continuous
# [llm][new_token]  cycle
# [llm][new_token] ,
# [llm][new_token]  where
# [llm][new_token]  code
# [llm][new_token]  is
# [llm][new_token]  written
# [llm][new_token] ,
# [llm][new_token]  tested
# [llm][new_token] ,
# [llm][new_token]  deployed
# [llm][new_token] ,
# [llm][new_token]  monitor
# [llm][new_token] ed
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  improved
# [llm][new_token]  in
# [llm][new_token]  an
# [llm][new_token]  iter
# [llm][new_token] ative
# [llm][new_token]  manner
# [llm][new_token] .
# [llm][new_token]  This
# [llm][new_token]  cycle
# [llm][new_token]  is
# [llm][new_token]  facil
# [llm][new_token] itated
# [llm][new_token]  by
# [llm][new_token]  using
# [llm][new_token]  autom
# [llm][new_token] ation
# [llm][new_token]  tools
# [llm][new_token]  and
# [llm][new_token]  techniques
# [llm][new_token]  to
# [llm][new_token]  stream
# [llm][new_token] line
# [llm][new_token]  processes
# [llm][new_token] ,
# [llm][new_token]  reduce
# [llm][new_token]  manual
# [llm][new_token]  inter
# [llm][new_token] vention
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  increase
# [llm][new_token]  efficiency
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token]
#
# [llm][new_token] The
# [llm][new_token]  key
# [llm][new_token]  components
# [llm][new_token]  of
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  include
# [llm][new_token] :
# [llm][new_token]
#
# [llm][new_token]
#
# [llm][new_token] 1
# [llm][new_token] .
# [llm][new_token]  Autom
# [llm][new_token] ation
# [llm][new_token] :
# [llm][new_token]  Autom
# [llm][new_token] ating
# [llm][new_token]  as
# [llm][new_token]  many
# [llm][new_token]  tasks
# [llm][new_token]  as
# [llm][new_token]  possible
# [llm][new_token] ,
# [llm][new_token]  such
# [llm][new_token]  as
# [llm][new_token]  building
# [llm][new_token] ,
# [llm][new_token]  testing
# [llm][new_token] ,
# [llm][new_token]  deploy
# [llm][new_token] ing
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  monitoring
# [llm][new_token]  code
# [llm][new_token] ,
# [llm][new_token]  to
# [llm][new_token]  reduce
# [llm][new_token]  the
# [llm][new_token]  risk
# [llm][new_token]  of
# [llm][new_token]  human
# [llm][new_token]  error
# [llm][new_token]  and
# [llm][new_token]  improve
# [llm][new_token]  efficiency
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 2
# [llm][new_token] .
# [llm][new_token]  Cont
# [llm][new_token] inu
# [llm][new_token] ous
# [llm][new_token]  Integr
# [llm][new_token] ation
# [llm][new_token]  (
# [llm][new_token] CI
# [llm][new_token] ):
# [llm][new_token]  Integr
# [llm][new_token] ating
# [llm][new_token]  code
# [llm][new_token]  changes
# [llm][new_token]  into
# [llm][new_token]  a
# [llm][new_token]  central
# [llm][new_token]  repository
# [llm][new_token]  frequently
# [llm][new_token] ,
# [llm][new_token]  usually
# [llm][new_token]  through
# [llm][new_token]  autom
# [llm][new_token] ated
# [llm][new_token]  processes
# [llm][new_token] ,
# [llm][new_token]  to
# [llm][new_token]  detect
# [llm][new_token]  and
# [llm][new_token]  resolve
# [llm][new_token]  issues
# [llm][new_token]  early
# [llm][new_token]  in
# [llm][new_token]  the
# [llm][new_token]  development
# [llm][new_token]  cycle
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 3
# [llm][new_token] .
# [llm][new_token]  Cont
# [llm][new_token] inu
# [llm][new_token] ous
# [llm][new_token]  D
# [llm][new_token] elivery
# [llm][new_token]  (
# [llm][new_token] CD
# [llm][new_token] ):
# [llm][new_token]  Del
# [llm][new_token] iver
# [llm][new_token] ing
# [llm][new_token]  software
# [llm][new_token]  changes
# [llm][new_token]  to
# [llm][new_token]  users
# [llm][new_token]  in
# [llm][new_token]  a
# [llm][new_token]  continuous
# [llm][new_token]  manner
# [llm][new_token] ,
# [llm][new_token]  rather
# [llm][new_token]  than
# [llm][new_token]  in
# [llm][new_token]  batch
# [llm][new_token] es
# [llm][new_token]  or
# [llm][new_token]  releases
# [llm][new_token] ,
# [llm][new_token]  to
# [llm][new_token]  provide
# [llm][new_token]  faster
# [llm][new_token]  time
# [llm][new_token] -
# [llm][new_token] to
# [llm][new_token] -
# [llm][new_token] market
# [llm][new_token]  and
# [llm][new_token]  improved
# [llm][new_token]  customer
# [llm][new_token]  satisfaction
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 4
# [llm][new_token] .
# [llm][new_token]  Cont
# [llm][new_token] inu
# [llm][new_token] ous
# [llm][new_token]  Mon
# [llm][new_token] itor
# [llm][new_token] ing
# [llm][new_token]  (
# [llm][new_token] CM
# [llm][new_token] ):
# [llm][new_token]  Mon
# [llm][new_token] itor
# [llm][new_token] ing
# [llm][new_token]  the
# [llm][new_token]  performance
# [llm][new_token]  and
# [llm][new_token]  behavior
# [llm][new_token]  of
# [llm][new_token]  software
# [llm][new_token]  in
# [llm][new_token]  real
# [llm][new_token] -
# [llm][new_token] time
# [llm][new_token] ,
# [llm][new_token]  using
# [llm][new_token]  autom
# [llm][new_token] ated
# [llm][new_token]  tools
# [llm][new_token]  and
# [llm][new_token]  techniques
# [llm][new_token] ,
# [llm][new_token]  to
# [llm][new_token]  detect
# [llm][new_token]  issues
# [llm][new_token]  early
# [llm][new_token]  and
# [llm][new_token]  improve
# [llm][new_token]  overall
# [llm][new_token]  quality
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 5
# [llm][new_token] .
# [llm][new_token]  Coll
# [llm][new_token] abor
# [llm][new_token] ation
# [llm][new_token] :
# [llm][new_token]  Enc
# [llm][new_token] ou
# [llm][new_token] rag
# [llm][new_token] ing
# [llm][new_token]  collaboration
# [llm][new_token]  between
# [llm][new_token]  developers
# [llm][new_token]  and
# [llm][new_token]  operators
# [llm][new_token]  through
# [llm][new_token]  open
# [llm][new_token]  communication
# [llm][new_token]  channels
# [llm][new_token] ,
# [llm][new_token]  shared
# [llm][new_token]  goals
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  a
# [llm][new_token]  common
# [llm][new_token]  understanding
# [llm][new_token]  of
# [llm][new_token]  the
# [llm][new_token]  software
# [llm][new_token]  delivery
# [llm][new_token]  process
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 6
# [llm][new_token] .
# [llm][new_token]  Autom
# [llm][new_token] ated
# [llm][new_token]  Test
# [llm][new_token] ing
# [llm][new_token] :
# [llm][new_token]  Using
# [llm][new_token]  autom
# [llm][new_token] ated
# [llm][new_token]  testing
# [llm][new_token]  tools
# [llm][new_token]  and
# [llm][new_token]  techniques
# [llm][new_token]  to
# [llm][new_token]  ensure
# [llm][new_token]  that
# [llm][new_token]  software
# [llm][new_token]  changes
# [llm][new_token]  are
# [llm][new_token]  thoroughly
# [llm][new_token]  tested
# [llm][new_token]  before
# [llm][new_token]  being
# [llm][new_token]  deployed
# [llm][new_token]  to
# [llm][new_token]  users
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 7
# [llm][new_token] .
# [llm][new_token]  In
# [llm][new_token] frastr
# [llm][new_token] ucture
# [llm][new_token]  as
# [llm][new_token]  Code
# [llm][new_token]  (
# [llm][new_token] I
# [llm][new_token] a
# [llm][new_token] C
# [llm][new_token] ):
# [llm][new_token]  Man
# [llm][new_token] aging
# [llm][new_token]  infrastr
# [llm][new_token] ucture
# [llm][new_token]  using
# [llm][new_token]  code
# [llm][new_token] ,
# [llm][new_token]  rather
# [llm][new_token]  than
# [llm][new_token]  through
# [llm][new_token]  manual
# [llm][new_token]  configuration
# [llm][new_token] ,
# [llm][new_token]  to
# [llm][new_token]  improve
# [llm][new_token]  efficiency
# [llm][new_token]  and
# [llm][new_token]  reduce
# [llm][new_token]  the
# [llm][new_token]  risk
# [llm][new_token]  of
# [llm][new_token]  human
# [llm][new_token]  error
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 8
# [llm][new_token] .
# [llm][new_token]  Mon
# [llm][new_token] itor
# [llm][new_token] ing
# [llm][new_token]  as
# [llm][new_token]  Code
# [llm][new_token] :
# [llm][new_token]  Using
# [llm][new_token]  autom
# [llm][new_token] ated
# [llm][new_token]  tools
# [llm][new_token]  and
# [llm][new_token]  techniques
# [llm][new_token]  to
# [llm][new_token]  monitor
# [llm][new_token]  the
# [llm][new_token]  performance
# [llm][new_token]  and
# [llm][new_token]  behavior
# [llm][new_token]  of
# [llm][new_token]  software
# [llm][new_token]  in
# [llm][new_token]  real
# [llm][new_token] -
# [llm][new_token] time
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  to
# [llm][new_token]  detect
# [llm][new_token]  issues
# [llm][new_token]  early
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 9
# [llm][new_token] .
# [llm][new_token]  Cont
# [llm][new_token] inu
# [llm][new_token] ous
# [llm][new_token]  Fe
# [llm][new_token] ed
# [llm][new_token] back
# [llm][new_token] :
# [llm][new_token]  Enc
# [llm][new_token] ou
# [llm][new_token] rag
# [llm][new_token] ing
# [llm][new_token]  continuous
# [llm][new_token]  feedback
# [llm][new_token]  from
# [llm][new_token]  users
# [llm][new_token]  and
# [llm][new_token]  st
# [llm][new_token] ake
# [llm][new_token] hold
# [llm][new_token] ers
# [llm][new_token]  throughout
# [llm][new_token]  the
# [llm][new_token]  software
# [llm][new_token]  delivery
# [llm][new_token]  process
# [llm][new_token] ,
# [llm][new_token]  to
# [llm][new_token]  improve
# [llm][new_token]  quality
# [llm][new_token]  and
# [llm][new_token]  satisfaction
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token] 1
# [llm][new_token] 0
# [llm][new_token] .
# [llm][new_token]  Culture
# [llm][new_token]  Change
# [llm][new_token] :
# [llm][new_token]  Ch
# [llm][new_token] anging
# [llm][new_token]  the
# [llm][new_token]  culture
# [llm][new_token]  of
# [llm][new_token]  both
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  operations
# [llm][new_token]  teams
# [llm][new_token]  to
# [llm][new_token]  em
# [llm][new_token] brace
# [llm][new_token]  collaboration
# [llm][new_token] ,
# [llm][new_token]  autom
# [llm][new_token] ation
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  continuous
# [llm][new_token]  improvement
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token]
#
# [llm][new_token] By
# [llm][new_token]  implementing
# [llm][new_token]  these
# [llm][new_token]  components
# [llm][new_token] ,
# [llm][new_token]  organizations
# [llm][new_token]  can
# [llm][new_token]  create
# [llm][new_token]  a
# [llm][new_token]  more
# [llm][new_token]  efficient
# [llm][new_token] ,
# [llm][new_token]  stream
# [llm][new_token] lined
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  ag
# [llm][new_token] ile
# [llm][new_token]  approach
# [llm][new_token]  to
# [llm][new_token]  software
# [llm][new_token]  delivery
# [llm][new_token] ,
# [llm][new_token]  which
# [llm][new_token]  can
# [llm][new_token]  lead
# [llm][new_token]  to
# [llm][new_token]  improved
# [llm][new_token]  customer
# [llm][new_token]  satisfaction
# [llm][new_token] ,
# [llm][new_token]  increased
# [llm][new_token]  speed
# [llm][new_token] -
# [llm][new_token] to
# [llm][new_token] -
# [llm][new_token] market
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  reduced
# [llm][new_token]  costs
# [llm][new_token] .
# [llm][new_token]
#
# [llm][new_token]
#
# [llm][new_token] In
# [llm][new_token]  summary
# [llm][new_token] ,
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  is
# [llm][new_token]  a
# [llm][new_token]  set
# [llm][new_token]  of
# [llm][new_token]  practices
# [llm][new_token]  that
# [llm][new_token]  comb
# [llm][new_token] ines
# [llm][new_token]  software
# [llm][new_token]  development
# [llm][new_token]  and
# [llm][new_token]  information
# [llm][new_token]  technology
# [llm][new_token]  operations
# [llm][new_token]  to
# [llm][new_token]  enh
# [llm][new_token] ance
# [llm][new_token]  collaboration
# [llm][new_token] ,
# [llm][new_token]  communication
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  autom
# [llm][new_token] ation
# [llm][new_token]  between
# [llm][new_token]  these
# [llm][new_token]  two
# [llm][new_token]  groups
# [llm][new_token] .
# [llm][new_token]  It
# [llm][new_token]  involves
# [llm][new_token]  tre
# [llm][new_token] ating
# [llm][new_token]  the
# [llm][new_token]  entire
# [llm][new_token]  software
# [llm][new_token]  delivery
# [llm][new_token]  process
# [llm][new_token]  as
# [llm][new_token]  a
# [llm][new_token]  continuous
# [llm][new_token]  cycle
# [llm][new_token] ,
# [llm][new_token]  using
# [llm][new_token]  autom
# [llm][new_token] ation
# [llm][new_token]  tools
# [llm][new_token]  and
# [llm][new_token]  techniques
# [llm][new_token]  to
# [llm][new_token]  stream
# [llm][new_token] line
# [llm][new_token]  processes
# [llm][new_token] ,
# [llm][new_token]  reduce
# [llm][new_token]  manual
# [llm][new_token]  inter
# [llm][new_token] vention
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  increase
# [llm][new_token]  efficiency
# [llm][new_token] .
# [llm][new_token]  The
# [llm][new_token]  key
# [llm][new_token]  components
# [llm][new_token]  of
# [llm][new_token]  Dev
# [llm][new_token] O
# [llm][new_token] ps
# [llm][new_token]  include
# [llm][new_token]  autom
# [llm][new_token] ation
# [llm][new_token] ,
# [llm][new_token]  continuous
# [llm][new_token]  integration
# [llm][new_token] ,
# [llm][new_token]  continuous
# [llm][new_token]  delivery
# [llm][new_token] ,
# [llm][new_token]  continuous
# [llm][new_token]  monitoring
# [llm][new_token] ,
# [llm][new_token]  collaboration
# [llm][new_token] ,
# [llm][new_token]  autom
# [llm][new_token] ated
# [llm][new_token]  testing
# [llm][new_token] ,
# [llm][new_token]  infrastr
# [llm][new_token] ucture
# [llm][new_token]  as
# [llm][new_token]  code
# [llm][new_token] ,
# [llm][new_token]  monitoring
# [llm][new_token]  as
# [llm][new_token]  code
# [llm][new_token] ,
# [llm][new_token]  continuous
# [llm][new_token]  feedback
# [llm][new_token] ,
# [llm][new_token]  and
# [llm][new_token]  culture
# [llm][new_token]  change
# [llm][new_token] .
# [llm][new_token]
#
# =============
# [llm][end] - generation
# DevOps is a set of practices that combines software development (Dev) and information technology operations (Ops) to enhance collaboration, communication, and automation between these two groups. The primary goal of DevOps is to break down the silos between development and operations teams and create a more streamlined and efficient approach to software delivery.
#
# At its core, DevOps is about creating a culture of collaboration and trust between developers and operators. It involves treating the entire software delivery process as a continuous cycle, where code is written, tested, deployed, monitored, and improved in an iterative manner. This cycle is facilitated by using automation tools and techniques to streamline processes, reduce manual intervention, and increase efficiency.
#
# The key components of DevOps include:
#
# 1. Automation: Automating as many tasks as possible, such as building, testing, deploying, and monitoring code, to reduce the risk of human error and improve efficiency.
# 2. Continuous Integration (CI): Integrating code changes into a central repository frequently, usually through automated processes, to detect and resolve issues early in the development cycle.
# 3. Continuous Delivery (CD): Delivering software changes to users in a continuous manner, rather than in batches or releases, to provide faster time-to-market and improved customer satisfaction.
# 4. Continuous Monitoring (CM): Monitoring the performance and behavior of software in real-time, using automated tools and techniques, to detect issues early and improve overall quality.
# 5. Collaboration: Encouraging collaboration between developers and operators through open communication channels, shared goals, and a common understanding of the software delivery process.
# 6. Automated Testing: Using automated testing tools and techniques to ensure that software changes are thoroughly tested before being deployed to users.
# 7. Infrastructure as Code (IaC): Managing infrastructure using code, rather than through manual configuration, to improve efficiency and reduce the risk of human error.
# 8. Monitoring as Code: Using automated tools and techniques to monitor the performance and behavior of software in real-time, and to detect issues early.
# 9. Continuous Feedback: Encouraging continuous feedback from users and stakeholders throughout the software delivery process, to improve quality and satisfaction.
# 10. Culture Change: Changing the culture of both development and operations teams to embrace collaboration, automation, and continuous improvement.
#
# By implementing these components, organizations can create a more efficient, streamlined, and agile approach to software delivery, which can lead to improved customer satisfaction, increased speed-to-market, and reduced costs.
#
# In summary, DevOps is a set of practices that combines software development and information technology operations to enhance collaboration, communication, and automation between these two groups. It involves treating the entire software delivery process as a continuous cycle, using automation tools and techniques to streamline processes, reduce manual intervention, and increase efficiency. The key components of DevOps include automation, continuous integration, continuous delivery, continuous monitoring, collaboration, automated testing, infrastructure as code, monitoring as code, continuous feedback, and culture change.
